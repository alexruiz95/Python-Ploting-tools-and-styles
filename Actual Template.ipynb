# %%
# Import packages 
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import style
import os,sys
# %matplotlib inline
from matplotlib import cycler

# %%
# Generate some data to be plotted
x = np.linspace(0,2*np.pi,20)
y = np.cos(x)

# %%
# The following %config line changes the inline figures to have a higher DPI.
# You can comment out (#) this line if you don't have a high-DPI (~220) display.
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Possible rcparms

# %%
IPython_default = plt.rcParams.copy()
IPython_default
# Out:
# {'_internal.classic_mode': False,
#  'agg.path.chunksize': 0,
#  'animation.avconv_args': [],
#  'animation.avconv_path': 'avconv',
#  'animation.bitrate': -1,
#  'animation.codec': 'h264',
#  'animation.convert_args': [],
#  'animation.convert_path': 'convert',
#  'animation.embed_limit': 20.0,
#  'animation.ffmpeg_args': [],
#  'animation.ffmpeg_path': 'ffmpeg',
#  'animation.frame_format': 'png',
#  'animation.html': 'none',
#  'animation.html_args': [],
#  'animation.writer': 'ffmpeg',
#  'axes.autolimit_mode': 'data',
#  'axes.axisbelow': 'line',
#  'axes.edgecolor': 'black',
#  'axes.facecolor': 'white',
#  'axes.formatter.limits': [-5, 6],
#  'axes.formatter.min_exponent': 0,
#  'axes.formatter.offset_threshold': 4,
#  'axes.formatter.use_locale': False,
#  'axes.formatter.use_mathtext': False,
#  'axes.formatter.useoffset': True,
#  'axes.grid': False,
#  'axes.grid.axis': 'both',
#  'axes.grid.which': 'major',
#  'axes.labelcolor': 'black',
#  'axes.labelpad': 4.0,
# ...

# %% [markdown]
# # Set rcparms

# %%
# %matplotlib inline

params = {'legend.fontsize': 13,#'x-large',
#           'figure.figsize': (7.2, 4.45),#(6, 4.5),
         'axes.labelsize':17,#'xx-large',
         'axes.titlesize':16,#'xx-large',
         'xtick.labelsize':16,#'xx-large',
         'ytick.labelsize':16,#'xx-large',
         'font.size':15,
         'mathtext.fontset': 'stix',
         'font.family': 'STIXGeneral',
         # 'font.family': ['serif'],
         # 'font.sans-serif' : 'Computer Modern Roman',
         'grid.color': '#c1c1c1',
         'text.usetex' : 'False', # set True and see if it works for your LaTeX installation
         'legend.framealpha' : '1.0',
         'lines.markersize': 6,
         'lines.markeredgewidth': '0.5',
          
#          # Axes properties
#         'axes.linewidth': 2,     # Thickness of axes
# #        'axes.labelpad': 10,     # Padding (whitespace) between the tick labels and the axis label
          
# #         # Set colors for which plot will cycle through 
# #         'axes.prop_cycle': cycler(color=['008fd5', 'fc4f30', 'e5ae38', '6d904f', '8b8b8b', '810f7c']),
         
#         # Tick properties
#             # x-axis
#             'xtick.top': 'True',      # tick marks on top
#             'xtick.direction': 'in',  # tick marks into graph, "in-wards"
#             'xtick.major.size': 7,    # size is the length of the ticks
#             'xtick.major.width': 2,   # width corresponds to the linewidth
#             'xtick.minor.size': 5,    # size is the length of the ticks
#             'xtick.minor.width': 2,   # width corresponds to the linewidth

#             # y-axis
#             'ytick.right': 'True',   # tick marks on top
#             'ytick.direction': 'in', # tick marks into graph, "in-wards"
#             'ytick.major.size': 7,   # size is the length of the ticks
#             'ytick.major.width': 2,  # width corresponds to the linewidth
#             'ytick.minor.size': 5,   # size is the length of the ticks
#             'ytick.minor.width': 2,  # width corresponds to the linewidth

          
#         # Line properties
#         'lines.linewidth': 2,
          
#         # Legend properties
#         'legend.framealpha': 1,     # 1,0 & False =  transparent 
#         'legend.frameon': 'True',  # 1 & true
          
#         # Grid lines
#         'axes.grid': 'True'
         
         }

    
plt.rcParams.update(params)


# colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

plt.rcParams['axes.prop_cycle'] = cycler(color=['r', 'g', 'b', 'y'])

shapes = ['X','o', 'd', 'v', '^', '<', '>', 'P', '8', 's', 'p', '*', 'h', 'H', 'D']

# %%
fig, ax = plt.subplots(2,3,figsize = (12,8),dpi=800)
for i, axes in enumerate(ax.flat):
    axes.plot(x,y, linestyle=':', marker = shapes[i],label='Data- ' + str(i))
    axes.plot(x,.5*y,linestyle=':', marker = shapes[i],label = 'Data ' + str(i))
    axes.set_title('Figure')
    axes.set_xlabel('X-label')
    axes.set_ylabel('Y-label')
    axes.legend()
#     axes.autoscale(tight=True)
# Fix spacing between subplots with either fig.tight_layout()
# plt.tight_layout()
plt.tight_layout()
# fig.savefig('figs/my_template3.pdf', dpi=800, bbox_inches='tight', transparent=True)
