# %%
# Install the science plot package
#!pip install git+https://github.com/garrettj403/SciencePlots.git

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import style
import os,sys
# %matplotlib inline
from matplotlib import cycler

# %%
# Generate some data to be plotted
x = np.linspace(0,2*np.pi,20)
y = np.cos(x)

# %%
# See what style are availble 
style.available

# %%
# The following %config line changes the inline figures to have a higher DPI.
# You can comment out (#) this line if you don't have a high-DPI (~220) display.
# %config InlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt
plt.style.use('science')

# %%
# Add supporting stuff
shapes = ['X','o', 'd', 'v', '^', '<', '>', 'P', '8', 's', 'p', '*', 'h', 'H', 'D']

# %%
fig, ax = plt.subplots(2,3,figsize = (12,8))
for i, axes in enumerate(ax.flat):
    axes.plot(x,y, linestyle=':', marker = shapes[i],label='Data: ' + str(i))
    axes.plot(x,.5*y,linestyle=':', marker = shapes[i],label = 'Data: ' + str(i))
    axes.set_title('Figure')
    axes.set_xlabel('X-label')
    axes.set_ylabel('Y-label')
    axes.legend()
    # fix arrangement
#     axes.autoscale(tight=True)
    
plt.tight_layout()
fig.savefig('figs/science.pdf', dpi=800, bbox_inches='tight', transparent=True)

# %% [markdown]
# -----METHOD 2 -----

# %%
with plt.style.context(['science', 'grid']):
    fig, ax = plt.subplots(2,3,figsize = (12,8))
    for i, axes in enumerate(ax.flat):
        axes.plot(x,y, linestyle=':', marker = shapes[i],label='Data: ' + str(i))
        axes.plot(x,.5*y,linestyle=':', marker = shapes[i],label = 'Data: ' + str(i))
        axes.set_title('Figure')
        axes.set_xlabel('X-label')
        axes.set_ylabel('Y-label')
        axes.legend()
    plt.tight_layout()
    fig.savefig('figs/science_grid.pdf', dpi=800, bbox_inches='tight', transparent=True)

# %%
with plt.style.context(['science', 'grid','scatter']):
    fig, ax = plt.subplots(2,3,figsize = (12,8))
    for i, axes in enumerate(ax.flat):
#         axes.plot(x,y, linestyle=':',label='Data: ' + str(i))
#         axes.plot(x,.5*y,linestyle=':',label = 'Data: ' + str(i))
        axes.plot(x,y, linestyle=':', marker = shapes[0],label='Data: ' + str(i))
        axes.plot(x,.5*y,linestyle=':', marker = shapes[1],label = 'Data: ' + str(i))
        axes.set_title('Figure')
        axes.set_xlabel('X-label')
        axes.set_ylabel('Y-label')
        axes.legend()
    
    plt.tight_layout()
    fig.savefig('figs/science_grid_scatter_shapes.pdf', dpi=800, bbox_inches='tight', transparent=True)

# %%
with plt.style.context(['science', 'grid','scatter']):
    science_grid_scatter_parms = plt.rcParams.copy()
science_grid_scatter_parms
# Out:
# {'_internal.classic_mode': False,
#  'agg.path.chunksize': 0,
#  'animation.avconv_args': [],
#  'animation.avconv_path': 'avconv',
#  'animation.bitrate': -1,
#  'animation.codec': 'h264',
#  'animation.convert_args': [],
#  'animation.convert_path': 'convert',
#  'animation.embed_limit': 20.0,
#  'animation.ffmpeg_args': [],
#  'animation.ffmpeg_path': 'ffmpeg',
#  'animation.frame_format': 'png',
#  'animation.html': 'none',
#  'animation.html_args': [],
#  'animation.writer': 'ffmpeg',
#  'axes.autolimit_mode': 'data',
#  'axes.axisbelow': 'line',
#  'axes.edgecolor': 'black',
#  'axes.facecolor': 'white',
#  'axes.formatter.limits': [-5, 6],
#  'axes.formatter.min_exponent': 0,
#  'axes.formatter.offset_threshold': 4,
#  'axes.formatter.use_locale': False,
#  'axes.formatter.use_mathtext': False,
#  'axes.formatter.useoffset': True,
#  'axes.grid': True,
#  'axes.grid.axis': 'both',
#  'axes.grid.which': 'major',
#  'axes.labelcolor': 'black',
#  'axes.labelpad': 4.0,
# ...

# %%
#figsize(width,height)
with plt.style.context(['science', 'grid','scatter']):
    fig, ax = plt.subplots(2,3,figsize = (8,6))
    for i, axes in enumerate(ax.flat):
#         axes.plot(x,y, linestyle=':',label='Data: ' + str(i))
#         axes.plot(x,.5*y,linestyle=':',label = 'Data: ' + str(i))
        axes.plot(x,y, linestyle=':', marker = shapes[0],label='Data: ' + str(i))
        axes.plot(x,.5*y,linestyle=':', marker = shapes[1],label = 'Data: ' + str(i))
        axes.set_title('Figure')
        axes.set_xlabel('X-label')
        axes.set_ylabel('Y-label')
        axes.legend()

    plt.tight_layout()
    fig.savefig('figs/science_grid_scatter_fit.pdf', dpi=800, bbox_inches='tight', transparent=True)

# %%
####

# %%
from mpl_toolkits import mplot3d
fig = plt.figure(figsize=(7,7))
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');

# %%
with plt.style.context(['vibrant']):
    science_grid_scatter_parms = plt.rcParams.copy()
science_grid_scatter_parms
# Out:
# {'_internal.classic_mode': False,
#  'agg.path.chunksize': 0,
#  'animation.avconv_args': [],
#  'animation.avconv_path': 'avconv',
#  'animation.bitrate': -1,
#  'animation.codec': 'h264',
#  'animation.convert_args': [],
#  'animation.convert_path': 'convert',
#  'animation.embed_limit': 20.0,
#  'animation.ffmpeg_args': [],
#  'animation.ffmpeg_path': 'ffmpeg',
#  'animation.frame_format': 'png',
#  'animation.html': 'none',
#  'animation.html_args': [],
#  'animation.writer': 'ffmpeg',
#  'axes.autolimit_mode': 'data',
#  'axes.axisbelow': 'line',
#  'axes.edgecolor': 'black',
#  'axes.facecolor': 'white',
#  'axes.formatter.limits': [-5, 6],
#  'axes.formatter.min_exponent': 0,
#  'axes.formatter.offset_threshold': 4,
#  'axes.formatter.use_locale': False,
#  'axes.formatter.use_mathtext': False,
#  'axes.formatter.useoffset': True,
#  'axes.grid': False,
#  'axes.grid.axis': 'both',
#  'axes.grid.which': 'major',
#  'axes.labelcolor': 'black',
#  'axes.labelpad': 4.0,
# ...
